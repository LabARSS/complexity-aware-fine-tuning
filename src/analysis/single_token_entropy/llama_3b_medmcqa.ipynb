# %%
import seaborn as sns

from reasoning_fine_tune.analysis.standard_analysis import standard_analysis_single_token_response

sns.set_theme(palette="deep")

standard_analysis_single_token_response(
    "../../../data/out/single_token_entropy/medmcqa_llama_3b.jsonl",
    "entropy_ans",
    "entropy_ans_correct",
    "entropy_value",
    "LLaMA 3B",
    include_masj=False,
)
# Out:
# entropy_ans
# A    1031
# B     773
# C     732
# D     462
# I       2
# Name: count, dtype: int64
# Total len = 3000
# Accuracy before filtering = 0.7130
# entropy_ans
# A    1031
# B     773
# C     732
# D     462
# I       2
# Name: count, dtype: int64
# Total len after filtering = 3000
#   category   roc_auc  accuracy     gini  num_samples     model         metric
# 0      ALL  0.810535     0.713  0.62107         3000  LLaMA 3B  entropy_value
