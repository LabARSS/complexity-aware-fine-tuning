# %%
import seaborn as sns

from reasoning_fine_tune.analysis.standard_analysis import standard_analysis_single_token_response

sns.set_theme(palette="deep")

standard_analysis_single_token_response(
    "../../../data/out/single_token_entropy/medmcqa_phi4mini.jsonl",
    "entropy_ans",
    "entropy_ans_correct",
    "entropy_value",
    "Phi 4 Mini",
    include_masj=False,
)
# Out:
# entropy_ans
# A    1148
# B     952
# C     559
# D     341
# Name: count, dtype: int64
# Total len = 3000
# Accuracy before filtering = 0.5897
# entropy_ans
# A    1148
# B     952
# C     559
# D     341
# Name: count, dtype: int64
# Total len after filtering = 3000
#   category   roc_auc  accuracy      gini  num_samples       model  \
# 0      ALL  0.757898  0.589667  0.515796         3000  Phi 4 Mini
#
#           metric
# 0  entropy_value
