# %%
import seaborn as sns

from reasoning_fine_tune.analysis.standard_analysis import standard_analysis_single_token_response

sns.set_theme(palette="deep")

standard_analysis_single_token_response(
    "../../../data/out/single_token_entropy/medmcqa_qwen_3b.jsonl",
    "entropy_ans",
    "entropy_ans_correct",
    "entropy_value",
    "Qwen 3B",
    include_masj=False,
)
# Out:
# entropy_ans
# A    1055
# B     841
# C     592
# D     511
# b       1
# Name: count, dtype: int64
# Total len = 3000
# Accuracy before filtering = 0.5713
# entropy_ans
# A    1055
# B     841
# C     592
# D     511
# b       1
# Name: count, dtype: int64
# Total len after filtering = 3000
#   category   roc_auc  accuracy      gini  num_samples    model         metric
# 0      ALL  0.725439  0.571333  0.450878         3000  Qwen 3B  entropy_value
